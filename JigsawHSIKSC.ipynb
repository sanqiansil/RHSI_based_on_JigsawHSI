# %% [markdown]
# # JigsawHSI for Hyper Spectral Image Classification
#
# **Author:** Jaime MORAGA
# **ORCID :** https://orcid.org/0000-0003-4483-9900

# %% [markdown]
# # Select dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/JigsawHSI
# Out:
# /content/drive/MyDrive/JigsawHSI

# %%
## GLOBAL VARIABLES
dataset = 'KSC'
# dataset = 'IP_99.74'
# dataset = 'PU_100'
# dataset = 'SA_100'

# %% [markdown]
# # Initialize all random functions with same seed

# %%
import os
# Use this before loading tensorflow
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # Block INFO messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # Block INFO and WARNING messages
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Block INFO, WARNING and ERROR messages
# https://www.tensorflow.org/api_docs/python/tf/autograph/set_verbosity
os.environ["AUTOGRAPH_VERBOSITY"] = "0"
import tensorflow as tf
tf.get_logger().setLevel("WARNING")

import random
import numpy as np

def random_seed():
    return os.urandom(42)

def reset_seeds(random_state = 42):
    try:
        tf.keras.utils.set_random_seed(random_state) # This resets all
        return 0
    except:
        random.seed(random_state)
        np.random.seed(random_state)
        tf.random.set_seed(random_state) # Tensorflow 2.9+
    try:
        from tensorflow import set_random_seed # Tensorflow 1.x
        set_random_seed(random_state)
        return 2
    except:
        pass
    return 1

max_gpus = len(tf.config.list_physical_devices('GPU'))

"""
Reset all random seeds
"""
r = reset_seeds(345)
del r

# %%
# %pip install spectral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spectral
#   Downloading spectral-0.23.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from spectral) (1.22.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.23.1

# %% [markdown]
# # Import libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
 
from sklearn.decomposition import FactorAnalysis, NMF
from sklearn.decomposition import PCA, TruncatedSVD
from operator import truediv

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

#!pip install spectral
import spectral

# %% [markdown]
# # Define functions

# %% [markdown]
# ## JigsawHSI definition

# %%
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Concatenate
from tensorflow.keras.layers import Conv2D, AveragePooling2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adadelta, SGD, Adam, Nadam, Adagrad, Adamax

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import utils as np_utils

#from skimage.transform import rotate
from tensorflow.keras.models import clone_model
from tensorflow.keras.utils import plot_model
#from tensorflow.keras.utils import multi_gpu_model

def jigsaw_m2( input_net, first_layer = None , internal_size = 13):
    # Creates internal filters as Inception: 1x1, 3x3, 5x5 ..., nxn 
    # Where n = internal_size
    jigsaw_t1_1x1 = Conv2D(256, (1,1), padding='same', activation = 'relu', 
                           kernel_regularizer = l2(0.002))(input_net)
    jigsaw_t1_3x3_reduce = Conv2D(96, (1,1), padding='same', activation = 'relu', 
                                  kernel_regularizer = l2(0.002))(input_net)
    jigsaw_t1_3x3 = Conv2D(128, (3,3), padding='same', activation = 'relu', 
                           kernel_regularizer = l2(0.002))(jigsaw_t1_3x3_reduce) # , name="i_3x3"
    if (internal_size >= 5):
        jigsaw_t1_5x5_reduce = Conv2D(16, (1,1), padding='same', activation = 'relu', 
                                      kernel_regularizer = l2(0.002))(input_net)
        jigsaw_t1_5x5 = Conv2D(128, (5,5), padding='same', activation = 'relu', 
                               kernel_regularizer = l2(0.002))(jigsaw_t1_5x5_reduce) # , name="i_5x5"
    if (internal_size >= 7):
        jigsaw_t1_7x7_reduce = Conv2D(16, (1,1), padding='same', activation = 'relu', 
                                      kernel_regularizer = l2(0.002))(input_net)
        jigsaw_t1_7x7 = Conv2D(128, (7,7), padding='same', activation = 'relu', 
                               kernel_regularizer = l2(0.002))(jigsaw_t1_7x7_reduce) # , name="i_7x7"
    if (internal_size >= 9):
        jigsaw_t1_9x9_reduce = Conv2D(16, (1,1), padding='same', activation = 'relu', 
                                      kernel_regularizer = l2(0.002))(input_net)
        jigsaw_t1_9x9 = Conv2D(64, (9,9), padding='same', activation = 'relu', 
                               kernel_regularizer = l2(0.002))(jigsaw_t1_9x9_reduce) # , name="i_9x9"
    if (internal_size >= 11):
        jigsaw_t1_11x11_reduce = Conv2D(16, (1,1), padding='same', activation = 'relu', 
                                        kernel_regularizer = l2(0.002))(input_net)
        jigsaw_t1_11x11 = Conv2D(64, (11,11), padding='same', activation = 'relu', 
                                 kernel_regularizer = l2(0.002))(jigsaw_t1_11x11_reduce) # , name="i_11x11"
    if (internal_size >= 13):
        jigsaw_t1_13x13_reduce = Conv2D(16, (1,1), padding='same', activation = 'relu', 
                                        kernel_regularizer = l2(0.002))(input_net)
        jigsaw_t1_13x13 = Conv2D(64, (13,13), padding='same', activation = 'relu', 
                                 kernel_regularizer = l2(0.002))(jigsaw_t1_13x13_reduce) # , name="i_13x13"
    jigsaw_t1_pool = MaxPooling2D(pool_size=(3,3), strides = (1,1), padding='same')(input_net)
    jigsaw_t1_pool_proj = Conv2D(32, (1,1), padding='same', activation = 'relu', 
                                 kernel_regularizer = l2(0.002))(jigsaw_t1_pool)
    jigsaw_list = [jigsaw_t1_1x1, jigsaw_t1_3x3]
    if (internal_size >= 5):
        jigsaw_list.append(jigsaw_t1_5x5)
    if (internal_size >= 7):
        jigsaw_list.append(jigsaw_t1_7x7)
    if (internal_size >= 9):
        jigsaw_list.append(jigsaw_t1_9x9)
    if (internal_size >= 11):
        jigsaw_list.append(jigsaw_t1_11x11)
    if (internal_size >= 13):
        jigsaw_list.append(jigsaw_t1_13x13)
    jigsaw_list.append(jigsaw_t1_pool_proj)
    if first_layer is not None:
        jigsaw_t1_first = Conv2D(96, (1,1), padding='same', activation = 'relu', 
                                 kernel_regularizer = l2(0.002))(first_layer)
        jigsaw_list.append(jigsaw_t1_first)
    jigsaw_t1_output = Concatenate(axis = -1)(jigsaw_list)
    return jigsaw_t1_output

def jigsaw_m_end(input_net, num_classes, first_layer = None):
    avg_pooling = AveragePooling2D(pool_size=(3,3), strides=(1,1), name='avg_pooling')(input_net)
    flat = Flatten()(avg_pooling)
    flat = Dense(16, kernel_regularizer=l2(0.002))(flat)
    flat = Dropout(0.4)(flat)
    if first_layer is not None:
        input_pixel = Flatten()(first_layer)
        input_pixel = Dense(16, kernel_regularizer=l2(0.002))(input_pixel)
        input_pixel = Dropout(0.2)(input_pixel)
        input_pixel = Dense(16, kernel_regularizer=l2(0.002))(input_pixel)
        input_pixel = Dropout(0.2)(input_pixel)
        flat = Concatenate(axis = -1)([input_pixel, flat])
    flat = Dense(32, kernel_regularizer=l2(0.002))(flat)
    avg_pooling = Dropout(0.4)(flat)
    loss3_classifier = Dense(num_classes, kernel_regularizer=l2(0.002))(avg_pooling)
    loss3_classifier_act = Activation('softmax', name='prob')(loss3_classifier)
    return loss3_classifier_act


# Builds model
def build_jigsawHSI(internal_size=13, num_classes=2, image_dim = (19, 19, 7), dimension_filters = None, verbose=1):
    my_input = Input( shape=image_dim )
    
    # Not needed for SA
    if ((dimension_filters is None) or (dimension_filters < 1)):
        conv1 = None
    else:
        conv1 = Conv2D(dimension_filters, (1,1), padding='same', activation = 'relu',
                      kernel_regularizer = l2(0.002), name='spectral_filter')(my_input)
    if(verbose>0):
        print(f"*** Building Jigsaw with up to {internal_size}x{internal_size} kernels")
    # One jigsaw module(s)
    jigsaw_01 = jigsaw_m2( my_input if conv1 is None else conv1, internal_size = internal_size )
    # For SA, the next two lines must be uncommented
    # jigsaw_01 = jigsaw_m2( jigsaw_01, first_layer=my_input, internal_size = internal_size )
    # jigsaw_01 = jigsaw_m2( jigsaw_01, internal_size = internal_size )
    
    # Attaches end to jigsaw modules, returns class within num_classes
    loss3_classifier_act = jigsaw_m_end(jigsaw_01,
                                    num_classes = num_classes,
                                    first_layer = my_input ) # testing num_classes
    model3 = Model( inputs = my_input, outputs = loss3_classifier_act )
    model3.compile(loss='binary_crossentropy', optimizer=Adadelta(), metrics=['accuracy'])
    return model3

# %%
class Kernel3D:
    def __init__(self, rows=3, cols=3, shape='rect', radius=None, no_value=np.NaN):
        if shape == 'circle':
            self.rows = 2*radius+1
            self.cols = 2*radius+1
            self.mask = self.round_mask(radius)
            self.row_buffer = radius
            self.col_buffer = radius
        else:
            self.rows = rows
            self.cols = cols
            self.mask = np.ones((rows, cols))
            self.row_buffer = int((rows-1)/2)
            self.col_buffer = int((cols-1)/2)
        self.mask = self.mask[np.newaxis, :, :]
        self.no_value = no_value
        assert((rows%2) == 1)
        assert((cols%2) == 1)

    def round_mask(self, radius):
        diameter = 2*radius+1
        mask = np.empty((diameter, diameter,))
        mask[:] = self.no_value
        sq_radius = radius**2
        for i in range(diameter):
            for j in range(diameter):
                if ((i-radius)**2+(j-radius)**2) <= sq_radius:
                    mask[i, j] = 1
        return mask

    def getSubset(self, matrix, row, column):
        m_rows = matrix.shape[1]
        assert (row >= self.row_buffer), f"Out of bounds row {row}, from {m_rows}"
        assert (row < (m_rows-self.row_buffer)), f"Out of bounds row {row}, from {m_rows}"
        m_cols = matrix.shape[2]
        assert((column >= self.col_buffer) and (column < (m_cols-self.col_buffer))), f"Out of bounds column {column}, from {m_cols}"
        row_start = row-self.row_buffer
        row_end = row+self.row_buffer
        column_start = column-self.col_buffer
        column_end = column+self.col_buffer
        small_matrix = matrix[:, row_start:row_end+1, column_start:column_end+1]
        return small_matrix*self.mask

class GeoTiffSlicer(object):
    def __init__(self, land_matrix, kernel_rows=None, kernel_cols=None,
                 kernel_shape='rect', kernel_radius=0, no_value = np.NaN):
        # (w, h, d) input tiff expected
        # (d, h, w) input tiff from rasterio must be transposed before calling this class
        if kernel_cols is None:
            kernel_cols = kernel_rows
        assert(kernel_cols < land_matrix.shape[2])
        assert(kernel_rows < land_matrix.shape[1])
        assert((kernel_shape == 'rect') or (kernel_shape == 'circle'))
        assert(kernel_radius>=0)
        if kernel_shape == 'rect':
            self.kernel = Kernel3D(rows=kernel_rows, cols=kernel_cols)
        else:
            self.kernel = Kernel3D(radius=kernel_radius,
                                   shape=kernel_shape,
                                   no_value=no_value)
            kernel_rows = kernel_cols = 2*kernel_radius+1
        self.kernel_rows = kernel_rows
        self.kernel_cols = kernel_cols
        self.land_matrix = land_matrix
        self.land_matrix_channels, self.land_matrix_cols, self.land_matrix_rows = land_matrix.shape
        self.land_matrix_cols = land_matrix.shape[2]
        self.land_matrix_rows = land_matrix.shape[1]
        self.land_matrix_channels = land_matrix.shape[0]
        self.small_row_min = self.kernel.row_buffer
        self.small_row_max = self.land_matrix_rows - self.small_row_min
        self.small_column_min = self.kernel.col_buffer
        self.small_column_max = self.land_matrix_cols - self.small_column_min

    def apply_mask(self, row, column):
        return self.kernel.getSubset(self.land_matrix, row=row, column=column)

# %% [markdown]
# ## Decompostion functions: reduce dimensionality

# %%
# Dimensionality reduction algorithms
def applyPCA(X, numComponents=75, random_state=0):
    newX = np.reshape(X, (-1, X.shape[2])) # Reshape to columns for each band
    pca = PCA(n_components=numComponents, whiten=True, random_state=random_state)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, 'pca'

def applyFA(X, numComponents=75, random_state=0):
    newX = np.reshape(X, (-1, X.shape[2])) # Reshape to columns for each band
    fa = FactorAnalysis(n_components=numComponents, random_state=random_state)
    newX = fa.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, 'fa'

def applySVD(X, numComponents=75, random_state=0):
    newX = np.reshape(X, (-1, X.shape[2])) # Reshape to columns for each band
    svd = TruncatedSVD(n_components=numComponents, random_state=random_state)
    newX = svd.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, 'svd'

def applyNMF(X, numComponents=75, random_state=0):
    newX = np.reshape(X, (-1, X.shape[2])) # Reshape to columns for each band
    nmf = NMF(n_components=numComponents, random_state=random_state)
    newX = nmf.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, 'nmf'

def applyNone(X, numComponents=75, random_state=0):
    return X, 'None'

# %% [markdown]
# ## Utilitary functions

# %%
def readData(dataset, data_path='./data'):
    data_dict = {
        'IP': ('Indian_pines_corrected.mat', 'indian_pines_corrected', 'Indian_pines_gt.mat', 'indian_pines_gt'),
        'SA': ('Salinas_corrected.mat', 'salinas_corrected', 'Salinas_gt.mat', 'salinas_gt'),
        'PU': ('PaviaU.mat', 'paviaU', 'PaviaU_gt.mat', 'paviaU_gt'),
        'KS': ('KSC.mat', 'KSC', 'KSC_gt.mat', 'KSC_gt')
    }
    (X_1, X_2, y_1, y_2) = data_dict.get(dataset[0:2].upper())
    X = sio.loadmat(os.path.join(data_path, X_1))[X_2]
    y = sio.loadmat(os.path.join(data_path, y_1))[y_2]
    
    return (X, y)

# %%
def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState,
                                                        stratify=y)
    return X_train, X_test, y_train, y_test

# %%
# Padding functions
def padWithZeros(X, margin=2):
    newX = np.pad(X, pad_width=((margin, margin),(margin, margin),(0, 0)), constant_values = 0)
    return newX

def padSymmetric(X, margin=2):
    newX = np.pad(X, pad_width=((margin, margin),(margin, margin),(0, 0)), mode = 'symmetric')
    return newX

# %%
def createImageCubes(X, y, window_size=8, removeZeroLabels = True):
    margin = int((window_size-1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], window_size, window_size, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1 , c - margin:c + margin + 1]   
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %% [markdown]
# # Load parameters from config file (config.ini)

# %%
import configparser
config = configparser.ConfigParser(inline_comment_prefixes=';#')
config.read_file(open('config.ini'))
config = config[dataset]

# %%
# Parse parameters and hyper-parameters from config file

test_ratio   = config.getfloat('test_ratio', 0.9)
window_size  = config.getint('window_size', 25)
num_channels = config.getint('num_channels', 3)
output_units = config.getint('output_units', 16)

filter_size  = config.getint('filter_size', 13)

batch_size   = config.getint('batch_size', 30)
max_epochs   = config.getint('max_epochs', 100)

decomp_func  = config.get('decomp_func', 'pca').lower()
optimizer_fn = config.get('optimizer_fn', 'sgd').lower()
optimizer_lr = config.getfloat('optimizer_lr', 0.01)
max_patience = config.getint('max_patience', 10)

hsi_filters  = config.get('hsi_filters', 'none')
hsi_filters  = None if (hsi_filters.lower() in ['none', '']) else int(hsi_filters)
print(hsi_filters)
# Out:
# None

# %% [markdown]
# ## Select proper optimizer and decomposition functions

# %%
dict_reduction={
    'fa' : (lambda X, numComponents: applyFA(X, numComponents=numComponents)),
    'nmf' : (lambda X, numComponents: applyNMF(X, numComponents=numComponents)),
    'pca': (lambda X, numComponents: applyPCA(X, numComponents=numComponents)),
    'svd': (lambda X, numComponents: applySVD(X, numComponents=numComponents)),
    'none': (lambda X, numComponents: applyNone(X, numComponents=numComponents))
}

DimReduction=dict_reduction.get(decomp_func)

dict_optimizer = {
    'sgd'     : SGD(learning_rate=optimizer_lr, momentum=0.9, nesterov=False),
    'adadelta': Adadelta(learning_rate=optimizer_lr, rho=0.95, epsilon=1e-07),
    'adam'    : Adam(learning_rate=optimizer_lr, epsilon=1e-07),
    'nadam'   : Nadam(learning_rate=optimizer_lr, epsilon=1e-07),
    'adamax'  : Adamax(learning_rate=optimizer_lr, epsilon=1e-07),
    'adagrad' : Adagrad(learning_rate=optimizer_lr, epsilon=1e-07)
}

FuncOptimizer = dict_optimizer.get(optimizer_fn)

# %%
# Define names of output files
best_model          = dataset + '-best-model.hdf5'
loss_curve          = dataset + '-loss-curve.png'
acc_curve           = dataset + '-acc-curve.png'
classification_file = dataset + '-classification_report.txt'
predictions_img     = dataset + '-predictions.png'
architecture_img    = dataset + '-architecture.png'

# %%
HSI, HSI_y = readData(dataset[0:2].upper())

HSI.shape, HSI_y.shape
# Out:
# ((512, 614, 176), (512, 614))

# %%
num_channels = np.min([HSI.shape[2], num_channels])

# %%
DRI, dim_reduction = DimReduction(HSI,numComponents=num_channels)

num_channels = DRI.shape[2]
DRI.shape
# Out:
# (512, 614, 10)

# %%
X, y = createImageCubes(DRI, HSI_y, window_size=window_size)

X.shape, y.shape

# %%
Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y, test_ratio)

Xtrain.shape, Xtest.shape, ytrain.shape, ytest.shape

# %%
Xtrain = Xtrain.reshape(-1, window_size, window_size, num_channels) #, 1)
Xtrain.shape
# Out:
# (1563, 27, 27, 10)

# %%
ytrain = np_utils.to_categorical(ytrain)
ytrain.shape
# Out:
# (1563, 13)

# %% [markdown]
# # Build network

# %%
input_shape =  (window_size, window_size, num_channels)
model = clone_model(build_jigsawHSI(internal_size = filter_size,
                      num_classes = output_units,
                      verbose=1,
                      dimension_filters=hsi_filters, # Was None,
                      image_dim = input_shape))
# Out:
# *** Building Jigsaw with up to 9x9 kernels

# %%
model.summary()
plot_model(model)
plot_model(model, to_file=architecture_img)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 27, 27, 10)] 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 96)   1056        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 27, 27, 10)   0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 27, 27, 256)  2816        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 27, 27, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 27, 27, 128)  51328       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 27, 27, 128)  100480      conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 27, 27, 64)   83008       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 27, 27, 32)   352         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 7290)         0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 27, 27, 736)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           116656      flatten_1[0][0]
# __________________________________________________________________________________________________
# avg_pooling (AveragePooling2D)  (None, 25, 25, 736)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 460000)       0           avg_pooling[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           272         dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           7360016     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dropout_2[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           1056        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 13)           429         dropout_3[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 13)           0           dense_4[0][0]
# ==================================================================================================
# Total params: 7,828,717
# Trainable params: 7,828,717
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Parallelize if gpus > 1
if (max_gpus>1):
    model = multi_gpu_model(model, gpus=max_gpus)
# Compile model
model.compile(loss='categorical_crossentropy', optimizer=FuncOptimizer, metrics=['accuracy'])

# %%
# Saves the best model, based on accuracy
checkpoint = ModelCheckpoint(best_model, monitor='accuracy', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
# If no early stopping desired, skip this cell
early_stop = EarlyStopping( monitor = 'loss',
                           min_delta=0.001,
                           mode='auto',
                           verbose=1, patience=max_patience)
callbacks_list = [checkpoint, early_stop]

# %%
# Summarize configuration
config_txt  = f'Configuration for dataset [{dataset}]:\n\n'
config_txt += f'Test Set Ratio: {test_ratio*100}% of samples\n'
config_txt += f'Window Size   : {window_size} pixels per side\n'
config_txt += f'Dim. Reduction: {dim_reduction} function\n'
config_txt += f'Num channels  : {num_channels} bands after {dim_reduction}\n'
config_txt += '# Network design\n'
config_txt += f'Input shape   : ({window_size}x{window_size}x{num_channels})\n'
config_txt += f'HSI Filters   : {hsi_filters} filters in first layer\n'
config_txt += f'Internal Size : ({filter_size}x{filter_size}) maximum network filter size\n'
config_txt += '# Training hyperparameters\n'
config_txt += f'Optimizer     : {optimizer_fn}\n'
config_txt += f'Learning rate : {optimizer_lr}\n'
config_txt += f'Batch Size    : {batch_size}\n'
config_txt += f'Num Epochs    : {max_epochs}\n' 
config_txt += f'Patience      : {max_patience}\n'
config_txt += '# Training GPUs\n'
config_txt += f'GPU Maximum   : {max_gpus}\n'
print(config_txt)
# Out:
# Configuration for dataset [KSC]:
#
# Test Set Ratio: 70.0% of samples
# Window Size   : 27 pixels per side
# Dim. Reduction: svd function
# Num channels  : 10 bands after svd
# # Network design
# Input shape   : (27x27x10)
# HSI Filters   : None filters in first layer
# Internal Size : (9x9) maximum network filter size
# # Training hyperparameters
# Optimizer     : adadelta
# Learning rate : 1.0
# Batch Size    : 106
# Num Epochs    : 600
# Patience      : 70
# # Training GPUs
# GPU Maximum   : 1

# %%
# Fit the model keeping the history
history = model.fit(x=Xtrain, y=ytrain, batch_size=batch_size, epochs=max_epochs, callbacks=callbacks_list)
# Out:
# Epoch 1/600
# 15/15 [==============================] - 9s 105ms/step - loss: 66069.9375 - accuracy: 0.2067
#
# Epoch 00001: accuracy improved from -inf to 0.20665, saving model to KSC-best-model.hdf5
# Epoch 2/600
# 15/15 [==============================] - 1s 61ms/step - loss: 18676.4473 - accuracy: 0.3711
#
# Epoch 00002: accuracy improved from 0.20665 to 0.37108, saving model to KSC-best-model.hdf5
# Epoch 3/600
# 15/15 [==============================] - 1s 59ms/step - loss: 10706.4219 - accuracy: 0.4907
#
# Epoch 00003: accuracy improved from 0.37108 to 0.49072, saving model to KSC-best-model.hdf5
# Epoch 4/600
# 15/15 [==============================] - 1s 58ms/step - loss: 7547.5176 - accuracy: 0.5323
#
# Epoch 00004: accuracy improved from 0.49072 to 0.53231, saving model to KSC-best-model.hdf5
# Epoch 5/600
# 15/15 [==============================] - 1s 58ms/step - loss: 6010.8862 - accuracy: 0.5419
#
# Epoch 00005: accuracy improved from 0.53231 to 0.54191, saving model to KSC-best-model.hdf5
# Epoch 6/600
# 15/15 [==============================] - 1s 58ms/step - loss: 5051.1626 - accuracy: 0.5771
#
# Epoch 00006: accuracy improved from 0.54191 to 0.57710, saving model to KSC-best-model.hdf5
# Epoch 7/600
# 15/15 [==============================] - 1s 59ms/step - loss: 3604.6453 - accuracy: 0.6097
#
# Epoch 00007: accuracy improved from 0.57710 to 0.60972, saving model to KSC-best-model.hdf5
# Epoch 8/600
# 15/15 [==============================] - 1s 59ms/step - loss: 3266.9197 - accuracy: 0.6225
#
# Epoch 00008: accuracy improved from 0.60972 to 0.62252, saving model to KSC-best-model.hdf5
# Epoch 9/600
# 15/15 [==============================] - 1s 58ms/step - loss: 2637.9382 - accuracy: 0.6647
#
# Epoch 00009: accuracy improved from 0.62252 to 0.66475, saving model to KSC-best-model.hdf5
# Epoch 10/600
# 15/15 [==============================] - 1s 59ms/step - loss: 2843.1301 - accuracy: 0.6500
#
# Epoch 00010: accuracy did not improve from 0.66475
# Epoch 11/600
# 15/15 [==============================] - 1s 59ms/step - loss: 2197.7378 - accuracy: 0.6667
#
# Epoch 00011: accuracy improved from 0.66475 to 0.66667, saving model to KSC-best-model.hdf5
# Epoch 12/600
# 15/15 [==============================] - 1s 59ms/step - loss: 1855.3359 - accuracy: 0.6820
#
# Epoch 00012: accuracy improved from 0.66667 to 0.68202, saving model to KSC-best-model.hdf5
# Epoch 13/600
# 15/15 [==============================] - 1s 58ms/step - loss: 2106.3259 - accuracy: 0.6929
#
# Epoch 00013: accuracy improved from 0.68202 to 0.69290, saving model to KSC-best-model.hdf5
# Epoch 14/600
# 15/15 [==============================] - 1s 58ms/step - loss: 1680.5216 - accuracy: 0.6961
#
# Epoch 00014: accuracy improved from 0.69290 to 0.69610, saving model to KSC-best-model.hdf5
# Epoch 15/600
# 15/15 [==============================] - 1s 59ms/step - loss: 2029.0625 - accuracy: 0.7083
#
# Epoch 00015: accuracy improved from 0.69610 to 0.70825, saving model to KSC-best-model.hdf5
# Epoch 16/600
# 15/15 [==============================] - 1s 59ms/step - loss: 1474.7897 - accuracy: 0.7268
#
# Epoch 00016: accuracy improved from 0.70825 to 0.72681, saving model to KSC-best-model.hdf5
# Epoch 17/600
# 15/15 [==============================] - 1s 58ms/step - loss: 1627.5890 - accuracy: 0.7294
#
# Epoch 00017: accuracy improved from 0.72681 to 0.72937, saving model to KSC-best-model.hdf5
# Epoch 18/600
# 15/15 [==============================] - 1s 58ms/step - loss: 1662.3698 - accuracy: 0.7281
#
# Epoch 00018: accuracy did not improve from 0.72937
# Epoch 19/600
# 15/15 [==============================] - 1s 59ms/step - loss: 1335.5176 - accuracy: 0.7415
#
# Epoch 00019: accuracy improved from 0.72937 to 0.74152, saving model to KSC-best-model.hdf5
# Epoch 20/600
# 15/15 [==============================] - 1s 59ms/step - loss: 1165.1356 - accuracy: 0.7626
#
# Epoch 00020: accuracy improved from 0.74152 to 0.76264, saving model to KSC-best-model.hdf5
# Epoch 21/600
# 15/15 [==============================] - 1s 58ms/step - loss: 1191.4153 - accuracy: 0.7582
#
# Epoch 00021: accuracy did not improve from 0.76264
# Epoch 22/600
# 15/15 [==============================] - 1s 59ms/step - loss: 874.3088 - accuracy: 0.7665
#
# Epoch 00022: accuracy improved from 0.76264 to 0.76647, saving model to KSC-best-model.hdf5
# Epoch 23/600
# 15/15 [==============================] - 1s 59ms/step - loss: 586.0739 - accuracy: 0.7837
#
# Epoch 00023: accuracy improved from 0.76647 to 0.78375, saving model to KSC-best-model.hdf5
# Epoch 24/600
# 15/15 [==============================] - 1s 58ms/step - loss: 854.8356 - accuracy: 0.7863
#
# Epoch 00024: accuracy improved from 0.78375 to 0.78631, saving model to KSC-best-model.hdf5
# Epoch 25/600
# 15/15 [==============================] - 1s 59ms/step - loss: 1003.6142 - accuracy: 0.7671
#
# Epoch 00025: accuracy did not improve from 0.78631
# Epoch 26/600
# 15/15 [==============================] - 1s 59ms/step - loss: 846.9565 - accuracy: 0.8029
#
# Epoch 00026: accuracy improved from 0.78631 to 0.80294, saving model to KSC-best-model.hdf5
# Epoch 27/600
# 15/15 [==============================] - 1s 58ms/step - loss: 583.1263 - accuracy: 0.7940
#
# Epoch 00027: accuracy did not improve from 0.80294
# Epoch 28/600
# 15/15 [==============================] - 1s 59ms/step - loss: 633.3673 - accuracy: 0.7953
#
# Epoch 00028: accuracy did not improve from 0.80294
# Epoch 29/600
# 15/15 [==============================] - 1s 59ms/step - loss: 566.6178 - accuracy: 0.8138
#
# Epoch 00029: accuracy improved from 0.80294 to 0.81382, saving model to KSC-best-model.hdf5
# Epoch 30/600
# 15/15 [==============================] - 1s 58ms/step - loss: 743.2112 - accuracy: 0.8036
#
# Epoch 00030: accuracy did not improve from 0.81382
# Epoch 31/600
# 15/15 [==============================] - 1s 59ms/step - loss: 879.8984 - accuracy: 0.8004
#
# Epoch 00031: accuracy did not improve from 0.81382
# Epoch 32/600
# 15/15 [==============================] - 1s 59ms/step - loss: 419.9580 - accuracy: 0.8260
#
# Epoch 00032: accuracy improved from 0.81382 to 0.82598, saving model to KSC-best-model.hdf5
# Epoch 33/600
# 15/15 [==============================] - 1s 58ms/step - loss: 602.9272 - accuracy: 0.8196
#
# Epoch 00033: accuracy did not improve from 0.82598
# Epoch 34/600
# 15/15 [==============================] - 1s 59ms/step - loss: 461.9293 - accuracy: 0.8273
#
# Epoch 00034: accuracy improved from 0.82598 to 0.82726, saving model to KSC-best-model.hdf5
# Epoch 35/600
# 15/15 [==============================] - 1s 59ms/step - loss: 537.0135 - accuracy: 0.8125
#
# Epoch 00035: accuracy did not improve from 0.82726
# Epoch 36/600
# 15/15 [==============================] - 1s 59ms/step - loss: 663.9404 - accuracy: 0.8241
#
# Epoch 00036: accuracy did not improve from 0.82726
# Epoch 37/600
# 15/15 [==============================] - 1s 59ms/step - loss: 761.4760 - accuracy: 0.8305
#
# Epoch 00037: accuracy improved from 0.82726 to 0.83045, saving model to KSC-best-model.hdf5
# Epoch 38/600
# 15/15 [==============================] - 1s 59ms/step - loss: 559.7199 - accuracy: 0.8273
#
# Epoch 00038: accuracy did not improve from 0.83045
# Epoch 39/600
# 15/15 [==============================] - 1s 59ms/step - loss: 494.4524 - accuracy: 0.8401
#
# Epoch 00039: accuracy improved from 0.83045 to 0.84005, saving model to KSC-best-model.hdf5
# Epoch 40/600
# 15/15 [==============================] - 1s 58ms/step - loss: 490.8267 - accuracy: 0.8426
#
# Epoch 00040: accuracy improved from 0.84005 to 0.84261, saving model to KSC-best-model.hdf5
# Epoch 41/600
# 15/15 [==============================] - 1s 59ms/step - loss: 490.1424 - accuracy: 0.8464
#
# Epoch 00041: accuracy improved from 0.84261 to 0.84645, saving model to KSC-best-model.hdf5
# Epoch 42/600
# 15/15 [==============================] - 1s 58ms/step - loss: 489.9637 - accuracy: 0.8541
#
# Epoch 00042: accuracy improved from 0.84645 to 0.85413, saving model to KSC-best-model.hdf5
# Epoch 43/600
# 15/15 [==============================] - 1s 58ms/step - loss: 300.8072 - accuracy: 0.8522
#
# Epoch 00043: accuracy did not improve from 0.85413
# Epoch 44/600
# 15/15 [==============================] - 1s 59ms/step - loss: 371.4578 - accuracy: 0.8644
#
# Epoch 00044: accuracy improved from 0.85413 to 0.86436, saving model to KSC-best-model.hdf5
# Epoch 45/600
# 15/15 [==============================] - 1s 58ms/step - loss: 372.3377 - accuracy: 0.8573
#
# Epoch 00045: accuracy did not improve from 0.86436
# Epoch 46/600
# 15/15 [==============================] - 1s 59ms/step - loss: 398.2308 - accuracy: 0.8484
#
# Epoch 00046: accuracy did not improve from 0.86436
# Epoch 47/600
# 15/15 [==============================] - 1s 59ms/step - loss: 361.3681 - accuracy: 0.8650
#
# Epoch 00047: accuracy improved from 0.86436 to 0.86500, saving model to KSC-best-model.hdf5
# Epoch 48/600
# 15/15 [==============================] - 1s 59ms/step - loss: 394.9711 - accuracy: 0.8560
#
# Epoch 00048: accuracy did not improve from 0.86500
# Epoch 49/600
# 15/15 [==============================] - 1s 58ms/step - loss: 295.6719 - accuracy: 0.8522
#
# Epoch 00049: accuracy did not improve from 0.86500
# Epoch 50/600
# 15/15 [==============================] - 1s 59ms/step - loss: 572.0311 - accuracy: 0.8624
#
# Epoch 00050: accuracy did not improve from 0.86500
# Epoch 51/600
# 15/15 [==============================] - 1s 59ms/step - loss: 219.0491 - accuracy: 0.8612
#
# Epoch 00051: accuracy did not improve from 0.86500
# Epoch 52/600
# 15/15 [==============================] - 1s 59ms/step - loss: 311.9530 - accuracy: 0.8752
#
# Epoch 00052: accuracy improved from 0.86500 to 0.87524, saving model to KSC-best-model.hdf5
# Epoch 53/600
# 15/15 [==============================] - 1s 59ms/step - loss: 172.8101 - accuracy: 0.8599
#
# Epoch 00053: accuracy did not improve from 0.87524
# Epoch 54/600
# 15/15 [==============================] - 1s 59ms/step - loss: 463.5042 - accuracy: 0.8823
#
# Epoch 00054: accuracy improved from 0.87524 to 0.88228, saving model to KSC-best-model.hdf5
# Epoch 55/600
# 15/15 [==============================] - 1s 59ms/step - loss: 325.1429 - accuracy: 0.8784
#
# Epoch 00055: accuracy did not improve from 0.88228
# Epoch 56/600
# 15/15 [==============================] - 1s 59ms/step - loss: 305.9161 - accuracy: 0.8868
#
# Epoch 00056: accuracy improved from 0.88228 to 0.88676, saving model to KSC-best-model.hdf5
# Epoch 57/600
# 15/15 [==============================] - 1s 59ms/step - loss: 287.3616 - accuracy: 0.8836
#
# Epoch 00057: accuracy did not improve from 0.88676
# Epoch 58/600
# 15/15 [==============================] - 1s 59ms/step - loss: 336.6805 - accuracy: 0.8842
#
# Epoch 00058: accuracy did not improve from 0.88676
# Epoch 59/600
# 15/15 [==============================] - 1s 59ms/step - loss: 338.6464 - accuracy: 0.8733
#
# Epoch 00059: accuracy did not improve from 0.88676
# Epoch 60/600
# 15/15 [==============================] - 1s 59ms/step - loss: 162.1235 - accuracy: 0.9047
#
# Epoch 00060: accuracy improved from 0.88676 to 0.90467, saving model to KSC-best-model.hdf5
# Epoch 61/600
# 15/15 [==============================] - 1s 59ms/step - loss: 207.3005 - accuracy: 0.9008
#
# Epoch 00061: accuracy did not improve from 0.90467
# Epoch 62/600
# 15/15 [==============================] - 1s 59ms/step - loss: 472.8956 - accuracy: 0.8976
#
# Epoch 00062: accuracy did not improve from 0.90467
# Epoch 63/600
# 15/15 [==============================] - 1s 59ms/step - loss: 197.0921 - accuracy: 0.9085
#
# Epoch 00063: accuracy improved from 0.90467 to 0.90851, saving model to KSC-best-model.hdf5
# Epoch 64/600
# 15/15 [==============================] - 1s 58ms/step - loss: 190.6685 - accuracy: 0.8983
#
# Epoch 00064: accuracy did not improve from 0.90851
# Epoch 65/600
# 15/15 [==============================] - 1s 59ms/step - loss: 262.6281 - accuracy: 0.8906
#
# Epoch 00065: accuracy did not improve from 0.90851
# Epoch 66/600
# 15/15 [==============================] - 1s 59ms/step - loss: 215.9583 - accuracy: 0.8746
#
# Epoch 00066: accuracy did not improve from 0.90851
# Epoch 67/600
# 15/15 [==============================] - 1s 59ms/step - loss: 149.8012 - accuracy: 0.9040
#
# Epoch 00067: accuracy did not improve from 0.90851
# Epoch 68/600
# 15/15 [==============================] - 1s 59ms/step - loss: 312.9682 - accuracy: 0.8944
#
# Epoch 00068: accuracy did not improve from 0.90851
# Epoch 69/600
# 15/15 [==============================] - 1s 59ms/step - loss: 170.0538 - accuracy: 0.8989
#
# Epoch 00069: accuracy did not improve from 0.90851
# Epoch 70/600
# 15/15 [==============================] - 1s 59ms/step - loss: 260.5849 - accuracy: 0.8957
#
# Epoch 00070: accuracy did not improve from 0.90851
# Epoch 71/600
# 15/15 [==============================] - 1s 58ms/step - loss: 293.2161 - accuracy: 0.9187
#
# Epoch 00071: accuracy improved from 0.90851 to 0.91875, saving model to KSC-best-model.hdf5
# Epoch 72/600
# 15/15 [==============================] - 1s 58ms/step - loss: 236.0852 - accuracy: 0.8976
#
# Epoch 00072: accuracy did not improve from 0.91875
# Epoch 73/600
# 15/15 [==============================] - 1s 59ms/step - loss: 337.1612 - accuracy: 0.9149
#
# Epoch 00073: accuracy did not improve from 0.91875
# Epoch 74/600
# 15/15 [==============================] - 1s 59ms/step - loss: 362.6857 - accuracy: 0.9187
#
# Epoch 00074: accuracy did not improve from 0.91875
# Epoch 75/600
# 15/15 [==============================] - 1s 59ms/step - loss: 277.4987 - accuracy: 0.9207
#
# Epoch 00075: accuracy improved from 0.91875 to 0.92067, saving model to KSC-best-model.hdf5
# Epoch 76/600
# 15/15 [==============================] - 1s 59ms/step - loss: 247.8709 - accuracy: 0.9085
#
# Epoch 00076: accuracy did not improve from 0.92067
# Epoch 77/600
# 15/15 [==============================] - 1s 59ms/step - loss: 187.9169 - accuracy: 0.9040
#
# Epoch 00077: accuracy did not improve from 0.92067
# Epoch 78/600
# 15/15 [==============================] - 1s 59ms/step - loss: 162.3983 - accuracy: 0.8976
#
# Epoch 00078: accuracy did not improve from 0.92067
# Epoch 79/600
# 15/15 [==============================] - 1s 59ms/step - loss: 186.8993 - accuracy: 0.9232
#
# Epoch 00079: accuracy improved from 0.92067 to 0.92322, saving model to KSC-best-model.hdf5
# Epoch 80/600
# 15/15 [==============================] - 1s 59ms/step - loss: 210.2392 - accuracy: 0.9296
#
# Epoch 00080: accuracy improved from 0.92322 to 0.92962, saving model to KSC-best-model.hdf5
# Epoch 81/600
# 15/15 [==============================] - 1s 60ms/step - loss: 227.8484 - accuracy: 0.9085
#
# Epoch 00081: accuracy did not improve from 0.92962
# Epoch 82/600
# 15/15 [==============================] - 1s 59ms/step - loss: 205.6390 - accuracy: 0.9136
#
# Epoch 00082: accuracy did not improve from 0.92962
# Epoch 83/600
# 15/15 [==============================] - 1s 59ms/step - loss: 245.0504 - accuracy: 0.9219
#
# Epoch 00083: accuracy did not improve from 0.92962
# Epoch 84/600
# 15/15 [==============================] - 1s 62ms/step - loss: 145.2318 - accuracy: 0.9296
#
# Epoch 00084: accuracy did not improve from 0.92962
# Epoch 85/600
# 15/15 [==============================] - 1s 63ms/step - loss: 235.0601 - accuracy: 0.9162
#
# Epoch 00085: accuracy did not improve from 0.92962
# Epoch 86/600
# 15/15 [==============================] - 1s 62ms/step - loss: 201.7034 - accuracy: 0.9296
#
# Epoch 00086: accuracy did not improve from 0.92962
# Epoch 87/600
# 15/15 [==============================] - 1s 61ms/step - loss: 169.7593 - accuracy: 0.9277
#
# Epoch 00087: accuracy did not improve from 0.92962
# Epoch 88/600
# 15/15 [==============================] - 1s 62ms/step - loss: 175.5644 - accuracy: 0.9309
#
# Epoch 00088: accuracy improved from 0.92962 to 0.93090, saving model to KSC-best-model.hdf5
# Epoch 89/600
# 15/15 [==============================] - 1s 61ms/step - loss: 168.7956 - accuracy: 0.9213
#
# Epoch 00089: accuracy did not improve from 0.93090
# Epoch 90/600
# 15/15 [==============================] - 1s 60ms/step - loss: 216.7240 - accuracy: 0.9181
#
# Epoch 00090: accuracy did not improve from 0.93090
# Epoch 91/600
# 15/15 [==============================] - 1s 60ms/step - loss: 134.9913 - accuracy: 0.9194
#
# Epoch 00091: accuracy did not improve from 0.93090
# Epoch 92/600
# 15/15 [==============================] - 1s 60ms/step - loss: 226.4919 - accuracy: 0.9207
#
# Epoch 00092: accuracy did not improve from 0.93090
# Epoch 93/600
# 15/15 [==============================] - 1s 59ms/step - loss: 125.9139 - accuracy: 0.9424
#
# Epoch 00093: accuracy improved from 0.93090 to 0.94242, saving model to KSC-best-model.hdf5
# Epoch 94/600
# 15/15 [==============================] - 1s 62ms/step - loss: 107.9598 - accuracy: 0.9155
#
# Epoch 00094: accuracy did not improve from 0.94242
# Epoch 95/600
# 15/15 [==============================] - 1s 59ms/step - loss: 198.9022 - accuracy: 0.9136
#
# Epoch 00095: accuracy did not improve from 0.94242
# Epoch 96/600
# 15/15 [==============================] - 1s 58ms/step - loss: 180.9778 - accuracy: 0.9443
#
# Epoch 00096: accuracy improved from 0.94242 to 0.94434, saving model to KSC-best-model.hdf5
# Epoch 97/600
# 15/15 [==============================] - 1s 57ms/step - loss: 111.3997 - accuracy: 0.9347
#
# Epoch 00097: accuracy did not improve from 0.94434
# Epoch 98/600
# 15/15 [==============================] - 1s 62ms/step - loss: 244.7140 - accuracy: 0.9175
#
# Epoch 00098: accuracy did not improve from 0.94434
# Epoch 99/600
# 15/15 [==============================] - 1s 60ms/step - loss: 148.2686 - accuracy: 0.9431
#
# Epoch 00099: accuracy did not improve from 0.94434
# Epoch 100/600
# 15/15 [==============================] - 1s 58ms/step - loss: 115.3316 - accuracy: 0.9386
#
# Epoch 00100: accuracy did not improve from 0.94434
# Epoch 101/600
# 15/15 [==============================] - 1s 59ms/step - loss: 274.3644 - accuracy: 0.9111
#
# Epoch 00101: accuracy did not improve from 0.94434
# Epoch 102/600
# 15/15 [==============================] - 1s 59ms/step - loss: 180.6795 - accuracy: 0.9322
#
# Epoch 00102: accuracy did not improve from 0.94434
# Epoch 103/600
# 15/15 [==============================] - 1s 64ms/step - loss: 74.7797 - accuracy: 0.9354
#
# Epoch 00103: accuracy did not improve from 0.94434
# Epoch 104/600
# 15/15 [==============================] - 1s 62ms/step - loss: 140.0033 - accuracy: 0.9379
#
# Epoch 00104: accuracy did not improve from 0.94434
# Epoch 105/600
# 15/15 [==============================] - 1s 60ms/step - loss: 87.7532 - accuracy: 0.9367
#
# Epoch 00105: accuracy did not improve from 0.94434
# Epoch 106/600
# 15/15 [==============================] - 1s 59ms/step - loss: 160.7150 - accuracy: 0.9251
#
# Epoch 00106: accuracy did not improve from 0.94434
# Epoch 107/600
# 15/15 [==============================] - 1s 59ms/step - loss: 116.4860 - accuracy: 0.9456
#
# Epoch 00107: accuracy improved from 0.94434 to 0.94562, saving model to KSC-best-model.hdf5
# Epoch 108/600
# 15/15 [==============================] - 1s 58ms/step - loss: 145.6718 - accuracy: 0.9437
#
# Epoch 00108: accuracy did not improve from 0.94562
# Epoch 109/600
# 15/15 [==============================] - 1s 58ms/step - loss: 69.2393 - accuracy: 0.9443
#
# Epoch 00109: accuracy did not improve from 0.94562
# Epoch 110/600
# 15/15 [==============================] - 1s 59ms/step - loss: 120.5614 - accuracy: 0.9405
#
# Epoch 00110: accuracy did not improve from 0.94562
# Epoch 111/600
# 15/15 [==============================] - 1s 63ms/step - loss: 146.8864 - accuracy: 0.9424
#
# Epoch 00111: accuracy did not improve from 0.94562
# Epoch 112/600
# 15/15 [==============================] - 1s 60ms/step - loss: 205.7022 - accuracy: 0.9437
#
# Epoch 00112: accuracy did not improve from 0.94562
# Epoch 113/600
# 15/15 [==============================] - 1s 60ms/step - loss: 239.2295 - accuracy: 0.9418
#
# Epoch 00113: accuracy did not improve from 0.94562
# Epoch 114/600
# 15/15 [==============================] - 1s 60ms/step - loss: 153.2367 - accuracy: 0.9559
#
# Epoch 00114: accuracy improved from 0.94562 to 0.95585, saving model to KSC-best-model.hdf5
# Epoch 115/600
# 15/15 [==============================] - 1s 60ms/step - loss: 122.1654 - accuracy: 0.9603
#
# Epoch 00115: accuracy improved from 0.95585 to 0.96033, saving model to KSC-best-model.hdf5
# Epoch 116/600
# 15/15 [==============================] - 1s 59ms/step - loss: 60.3268 - accuracy: 0.9501
#
# Epoch 00116: accuracy did not improve from 0.96033
# Epoch 117/600
# 15/15 [==============================] - 1s 60ms/step - loss: 113.9520 - accuracy: 0.9399
#
# Epoch 00117: accuracy did not improve from 0.96033
# Epoch 118/600
# 15/15 [==============================] - 1s 59ms/step - loss: 245.6563 - accuracy: 0.9296
#
# Epoch 00118: accuracy did not improve from 0.96033
# Epoch 119/600
# 15/15 [==============================] - 1s 59ms/step - loss: 97.3660 - accuracy: 0.9488
#
# Epoch 00119: accuracy did not improve from 0.96033
# Epoch 120/600
# 15/15 [==============================] - 1s 59ms/step - loss: 254.3815 - accuracy: 0.9303
#
# Epoch 00120: accuracy did not improve from 0.96033
# Epoch 121/600
# 15/15 [==============================] - 1s 58ms/step - loss: 126.1780 - accuracy: 0.9514
#
# Epoch 00121: accuracy did not improve from 0.96033
# Epoch 122/600
# 15/15 [==============================] - 1s 59ms/step - loss: 158.6018 - accuracy: 0.9507
#
# Epoch 00122: accuracy did not improve from 0.96033
# Epoch 123/600
# 15/15 [==============================] - 1s 59ms/step - loss: 59.2382 - accuracy: 0.9463
#
# Epoch 00123: accuracy did not improve from 0.96033
# Epoch 124/600
# 15/15 [==============================] - 1s 59ms/step - loss: 184.0710 - accuracy: 0.9552
#
# Epoch 00124: accuracy did not improve from 0.96033
# Epoch 125/600
# 15/15 [==============================] - 1s 59ms/step - loss: 183.4063 - accuracy: 0.9584
#
# Epoch 00125: accuracy did not improve from 0.96033
# Epoch 126/600
# 15/15 [==============================] - 1s 59ms/step - loss: 84.2142 - accuracy: 0.9603
#
# Epoch 00126: accuracy did not improve from 0.96033
# Epoch 127/600
# 15/15 [==============================] - 1s 58ms/step - loss: 65.5070 - accuracy: 0.9507
#
# Epoch 00127: accuracy did not improve from 0.96033
# Epoch 128/600
# 15/15 [==============================] - 1s 59ms/step - loss: 164.1544 - accuracy: 0.9341
#
# Epoch 00128: accuracy did not improve from 0.96033
# Epoch 129/600
# 15/15 [==============================] - 1s 59ms/step - loss: 35.9172 - accuracy: 0.9648
#
# Epoch 00129: accuracy improved from 0.96033 to 0.96481, saving model to KSC-best-model.hdf5
# Epoch 130/600
# 15/15 [==============================] - 1s 59ms/step - loss: 94.9854 - accuracy: 0.9495
#
# Epoch 00130: accuracy did not improve from 0.96481
# Epoch 131/600
# 15/15 [==============================] - 1s 59ms/step - loss: 151.8553 - accuracy: 0.9469
#
# Epoch 00131: accuracy did not improve from 0.96481
# Epoch 132/600
# 15/15 [==============================] - 1s 59ms/step - loss: 240.4120 - accuracy: 0.9347
#
# Epoch 00132: accuracy did not improve from 0.96481
# Epoch 133/600
# 15/15 [==============================] - 1s 59ms/step - loss: 134.3494 - accuracy: 0.9335
#
# Epoch 00133: accuracy did not improve from 0.96481
# Epoch 134/600
# 15/15 [==============================] - 1s 58ms/step - loss: 72.4390 - accuracy: 0.9456
#
# Epoch 00134: accuracy did not improve from 0.96481
# Epoch 135/600
# 15/15 [==============================] - 1s 59ms/step - loss: 84.5655 - accuracy: 0.9527
#
# Epoch 00135: accuracy did not improve from 0.96481
# Epoch 136/600
# 15/15 [==============================] - 1s 58ms/step - loss: 191.2285 - accuracy: 0.9571
#
# Epoch 00136: accuracy did not improve from 0.96481
# Epoch 137/600
# 15/15 [==============================] - 1s 58ms/step - loss: 137.3333 - accuracy: 0.9629
#
# Epoch 00137: accuracy did not improve from 0.96481
# Epoch 138/600
# 15/15 [==============================] - 1s 59ms/step - loss: 73.2555 - accuracy: 0.9527
#
# Epoch 00138: accuracy did not improve from 0.96481
# Epoch 139/600
# 15/15 [==============================] - 1s 59ms/step - loss: 145.8529 - accuracy: 0.9546
#
# Epoch 00139: accuracy did not improve from 0.96481
# Epoch 140/600
# 15/15 [==============================] - 1s 59ms/step - loss: 156.3331 - accuracy: 0.9584
#
# Epoch 00140: accuracy did not improve from 0.96481
# Epoch 141/600
# 15/15 [==============================] - 1s 59ms/step - loss: 84.2460 - accuracy: 0.9450
#
# Epoch 00141: accuracy did not improve from 0.96481
# Epoch 142/600
# 15/15 [==============================] - 1s 59ms/step - loss: 51.6527 - accuracy: 0.9584
#
# Epoch 00142: accuracy did not improve from 0.96481
# Epoch 143/600
# 15/15 [==============================] - 1s 58ms/step - loss: 68.7894 - accuracy: 0.9520
#
# Epoch 00143: accuracy did not improve from 0.96481
# Epoch 144/600
# 15/15 [==============================] - 1s 59ms/step - loss: 133.7003 - accuracy: 0.9552
#
# Epoch 00144: accuracy did not improve from 0.96481
# Epoch 145/600
# 15/15 [==============================] - 1s 58ms/step - loss: 120.9956 - accuracy: 0.9539
#
# Epoch 00145: accuracy did not improve from 0.96481
# Epoch 146/600
# 15/15 [==============================] - 1s 59ms/step - loss: 146.8100 - accuracy: 0.9482
#
# Epoch 00146: accuracy did not improve from 0.96481
# Epoch 147/600
# 15/15 [==============================] - 1s 59ms/step - loss: 83.1194 - accuracy: 0.9629
#
# Epoch 00147: accuracy did not improve from 0.96481
# Epoch 148/600
# 15/15 [==============================] - 1s 59ms/step - loss: 124.9320 - accuracy: 0.9597
#
# Epoch 00148: accuracy did not improve from 0.96481
# Epoch 149/600
# 15/15 [==============================] - 1s 59ms/step - loss: 137.2045 - accuracy: 0.9520
#
# Epoch 00149: accuracy did not improve from 0.96481
# Epoch 150/600
# 15/15 [==============================] - 1s 59ms/step - loss: 122.9828 - accuracy: 0.9520
#
# Epoch 00150: accuracy did not improve from 0.96481
# Epoch 151/600
# 15/15 [==============================] - 1s 59ms/step - loss: 134.8301 - accuracy: 0.9591
#
# Epoch 00151: accuracy did not improve from 0.96481
# Epoch 152/600
# 15/15 [==============================] - 1s 59ms/step - loss: 141.5853 - accuracy: 0.9667
#
# Epoch 00152: accuracy improved from 0.96481 to 0.96673, saving model to KSC-best-model.hdf5
# Epoch 153/600
# 15/15 [==============================] - 1s 58ms/step - loss: 132.3011 - accuracy: 0.9527
#
# Epoch 00153: accuracy did not improve from 0.96673
# Epoch 154/600
# 15/15 [==============================] - 1s 59ms/step - loss: 92.6906 - accuracy: 0.9603
#
# Epoch 00154: accuracy did not improve from 0.96673
# Epoch 155/600
# 15/15 [==============================] - 1s 59ms/step - loss: 55.6485 - accuracy: 0.9782
#
# Epoch 00155: accuracy improved from 0.96673 to 0.97825, saving model to KSC-best-model.hdf5
# Epoch 156/600
# 15/15 [==============================] - 1s 59ms/step - loss: 59.8971 - accuracy: 0.9546
#
# Epoch 00156: accuracy did not improve from 0.97825
# Epoch 157/600
# 15/15 [==============================] - 1s 59ms/step - loss: 51.6296 - accuracy: 0.9591
#
# Epoch 00157: accuracy did not improve from 0.97825
# Epoch 158/600
# 15/15 [==============================] - 1s 59ms/step - loss: 197.8038 - accuracy: 0.9559
#
# Epoch 00158: accuracy did not improve from 0.97825
# Epoch 159/600
# 15/15 [==============================] - 1s 59ms/step - loss: 133.9919 - accuracy: 0.9373
#
# Epoch 00159: accuracy did not improve from 0.97825
# Epoch 160/600
# 15/15 [==============================] - 1s 59ms/step - loss: 80.9504 - accuracy: 0.9629
#
# Epoch 00160: accuracy did not improve from 0.97825
# Epoch 161/600
# 15/15 [==============================] - 1s 59ms/step - loss: 133.4416 - accuracy: 0.9629
#
# Epoch 00161: accuracy did not improve from 0.97825
# Epoch 162/600
# 15/15 [==============================] - 1s 59ms/step - loss: 121.1527 - accuracy: 0.9648
#
# Epoch 00162: accuracy did not improve from 0.97825
# Epoch 163/600
# 15/15 [==============================] - 1s 59ms/step - loss: 109.6482 - accuracy: 0.9693
#
# Epoch 00163: accuracy did not improve from 0.97825
# Epoch 164/600
# 15/15 [==============================] - 1s 59ms/step - loss: 111.7445 - accuracy: 0.9642
#
# Epoch 00164: accuracy did not improve from 0.97825
# Epoch 165/600
# 15/15 [==============================] - 1s 59ms/step - loss: 124.8561 - accuracy: 0.9667
#
# Epoch 00165: accuracy did not improve from 0.97825
# Epoch 166/600
# 15/15 [==============================] - 1s 59ms/step - loss: 214.1834 - accuracy: 0.9616
#
# Epoch 00166: accuracy did not improve from 0.97825
# Epoch 167/600
# 15/15 [==============================] - 1s 59ms/step - loss: 62.8302 - accuracy: 0.9578
#
# Epoch 00167: accuracy did not improve from 0.97825
# Epoch 168/600
# 15/15 [==============================] - 1s 59ms/step - loss: 54.7306 - accuracy: 0.9623
#
# Epoch 00168: accuracy did not improve from 0.97825
# Epoch 169/600
# 15/15 [==============================] - 1s 59ms/step - loss: 154.5079 - accuracy: 0.9578
#
# Epoch 00169: accuracy did not improve from 0.97825
# Epoch 170/600
# 15/15 [==============================] - 1s 59ms/step - loss: 122.9288 - accuracy: 0.9623
#
# Epoch 00170: accuracy did not improve from 0.97825
# Epoch 171/600
# 15/15 [==============================] - 1s 59ms/step - loss: 130.9816 - accuracy: 0.9635
#
# Epoch 00171: accuracy did not improve from 0.97825
# Epoch 172/600
# 15/15 [==============================] - 1s 59ms/step - loss: 178.3221 - accuracy: 0.9635
#
# Epoch 00172: accuracy did not improve from 0.97825
# Epoch 173/600
# 15/15 [==============================] - 1s 59ms/step - loss: 176.0868 - accuracy: 0.9629
#
# Epoch 00173: accuracy did not improve from 0.97825
# Epoch 174/600
# 15/15 [==============================] - 1s 59ms/step - loss: 155.0154 - accuracy: 0.9584
#
# Epoch 00174: accuracy did not improve from 0.97825
# Epoch 175/600
# 15/15 [==============================] - 1s 59ms/step - loss: 53.2753 - accuracy: 0.9706
#
# Epoch 00175: accuracy did not improve from 0.97825
# Epoch 176/600
# 15/15 [==============================] - 1s 59ms/step - loss: 76.8900 - accuracy: 0.9610
#
# Epoch 00176: accuracy did not improve from 0.97825
# Epoch 177/600
# 15/15 [==============================] - 1s 59ms/step - loss: 146.9670 - accuracy: 0.9514
#
# Epoch 00177: accuracy did not improve from 0.97825
# Epoch 178/600
# 15/15 [==============================] - 1s 59ms/step - loss: 130.0632 - accuracy: 0.9584
#
# Epoch 00178: accuracy did not improve from 0.97825
# Epoch 179/600
# 15/15 [==============================] - 1s 59ms/step - loss: 58.4081 - accuracy: 0.9699
#
# Epoch 00179: accuracy did not improve from 0.97825
# Epoch 180/600
# 15/15 [==============================] - 1s 59ms/step - loss: 59.9363 - accuracy: 0.9603
#
# Epoch 00180: accuracy did not improve from 0.97825
# Epoch 181/600
# 15/15 [==============================] - 1s 59ms/step - loss: 59.6165 - accuracy: 0.9661
#
# Epoch 00181: accuracy did not improve from 0.97825
# Epoch 182/600
# 15/15 [==============================] - 1s 58ms/step - loss: 78.6313 - accuracy: 0.9706
#
# Epoch 00182: accuracy did not improve from 0.97825
# Epoch 183/600
# 15/15 [==============================] - 1s 59ms/step - loss: 129.7321 - accuracy: 0.9661
#
# Epoch 00183: accuracy did not improve from 0.97825
# Epoch 184/600
# 15/15 [==============================] - 1s 59ms/step - loss: 97.3015 - accuracy: 0.9667
#
# Epoch 00184: accuracy did not improve from 0.97825
# Epoch 185/600
# 15/15 [==============================] - 1s 59ms/step - loss: 96.2625 - accuracy: 0.9642
#
# Epoch 00185: accuracy did not improve from 0.97825
# Epoch 186/600
# 15/15 [==============================] - 1s 59ms/step - loss: 199.3947 - accuracy: 0.9680
#
# Epoch 00186: accuracy did not improve from 0.97825
# Epoch 187/600
# 15/15 [==============================] - 1s 59ms/step - loss: 96.9430 - accuracy: 0.9699
#
# Epoch 00187: accuracy did not improve from 0.97825
# Epoch 188/600
# 15/15 [==============================] - 1s 58ms/step - loss: 46.5637 - accuracy: 0.9642
#
# Epoch 00188: accuracy did not improve from 0.97825
# Epoch 189/600
# 15/15 [==============================] - 1s 59ms/step - loss: 75.2964 - accuracy: 0.9648
#
# Epoch 00189: accuracy did not improve from 0.97825
# Epoch 190/600
# 15/15 [==============================] - 1s 59ms/step - loss: 102.6445 - accuracy: 0.9635
#
# Epoch 00190: accuracy did not improve from 0.97825
# Epoch 191/600
# 15/15 [==============================] - 1s 58ms/step - loss: 108.4282 - accuracy: 0.9597
#
# Epoch 00191: accuracy did not improve from 0.97825
# Epoch 192/600
# 15/15 [==============================] - 1s 59ms/step - loss: 76.6426 - accuracy: 0.9744
#
# Epoch 00192: accuracy did not improve from 0.97825
# Epoch 193/600
# 15/15 [==============================] - 1s 59ms/step - loss: 37.3498 - accuracy: 0.9687
#
# Epoch 00193: accuracy did not improve from 0.97825
# Epoch 194/600
# 15/15 [==============================] - 1s 58ms/step - loss: 79.2613 - accuracy: 0.9667
#
# Epoch 00194: accuracy did not improve from 0.97825
# Epoch 195/600
# 15/15 [==============================] - 1s 58ms/step - loss: 30.5325 - accuracy: 0.9763
#
# Epoch 00195: accuracy did not improve from 0.97825
# Epoch 196/600
# 15/15 [==============================] - 1s 59ms/step - loss: 30.6102 - accuracy: 0.9718
#
# Epoch 00196: accuracy did not improve from 0.97825
# Epoch 197/600
# 15/15 [==============================] - 1s 59ms/step - loss: 122.3518 - accuracy: 0.9718
#
# Epoch 00197: accuracy did not improve from 0.97825
# Epoch 198/600
# 15/15 [==============================] - 1s 59ms/step - loss: 190.0257 - accuracy: 0.9546
#
# Epoch 00198: accuracy did not improve from 0.97825
# Epoch 199/600
# 15/15 [==============================] - 1s 59ms/step - loss: 82.4357 - accuracy: 0.9648
#
# Epoch 00199: accuracy did not improve from 0.97825
# Epoch 200/600
# 15/15 [==============================] - 1s 59ms/step - loss: 102.4670 - accuracy: 0.9661
#
# Epoch 00200: accuracy did not improve from 0.97825
# Epoch 201/600
# 15/15 [==============================] - 1s 59ms/step - loss: 24.8943 - accuracy: 0.9827
#
# Epoch 00201: accuracy improved from 0.97825 to 0.98273, saving model to KSC-best-model.hdf5
# Epoch 202/600
# 15/15 [==============================] - 1s 58ms/step - loss: 36.8475 - accuracy: 0.9680
#
# Epoch 00202: accuracy did not improve from 0.98273
# Epoch 203/600
# 15/15 [==============================] - 1s 59ms/step - loss: 111.5374 - accuracy: 0.9674
#
# Epoch 00203: accuracy did not improve from 0.98273
# Epoch 204/600
# 15/15 [==============================] - 1s 59ms/step - loss: 67.7750 - accuracy: 0.9693
#
# Epoch 00204: accuracy did not improve from 0.98273
# Epoch 205/600
# 15/15 [==============================] - 1s 59ms/step - loss: 138.1163 - accuracy: 0.9674
#
# Epoch 00205: accuracy did not improve from 0.98273
# Epoch 206/600
# 15/15 [==============================] - 1s 59ms/step - loss: 63.1180 - accuracy: 0.9578
#
# Epoch 00206: accuracy did not improve from 0.98273
# Epoch 207/600
# 15/15 [==============================] - 1s 59ms/step - loss: 123.7551 - accuracy: 0.9731
#
# Epoch 00207: accuracy did not improve from 0.98273
# Epoch 208/600
# 15/15 [==============================] - 1s 58ms/step - loss: 148.0580 - accuracy: 0.9725
#
# Epoch 00208: accuracy did not improve from 0.98273
# Epoch 209/600
# 15/15 [==============================] - 1s 59ms/step - loss: 230.5016 - accuracy: 0.9597
#
# Epoch 00209: accuracy did not improve from 0.98273
# Epoch 210/600
# 15/15 [==============================] - 1s 59ms/step - loss: 12.0800 - accuracy: 0.9827
#
# Epoch 00210: accuracy did not improve from 0.98273
# Epoch 211/600
# 15/15 [==============================] - 1s 59ms/step - loss: 57.1361 - accuracy: 0.9808
#
# Epoch 00211: accuracy did not improve from 0.98273
# Epoch 212/600
# 15/15 [==============================] - 1s 59ms/step - loss: 51.9343 - accuracy: 0.9725
#
# Epoch 00212: accuracy did not improve from 0.98273
# Epoch 213/600
# 15/15 [==============================] - 1s 59ms/step - loss: 266.2208 - accuracy: 0.9687
#
# Epoch 00213: accuracy did not improve from 0.98273
# Epoch 214/600
# 15/15 [==============================] - 1s 59ms/step - loss: 48.6885 - accuracy: 0.9763
#
# Epoch 00214: accuracy did not improve from 0.98273
# Epoch 215/600
# 15/15 [==============================] - 1s 59ms/step - loss: 115.5833 - accuracy: 0.9680
#
# Epoch 00215: accuracy did not improve from 0.98273
# Epoch 216/600
# 15/15 [==============================] - 1s 59ms/step - loss: 27.7010 - accuracy: 0.9821
#
# Epoch 00216: accuracy did not improve from 0.98273
# Epoch 217/600
# 15/15 [==============================] - 1s 59ms/step - loss: 44.0847 - accuracy: 0.9763
#
# Epoch 00217: accuracy did not improve from 0.98273
# Epoch 218/600
# 15/15 [==============================] - 1s 58ms/step - loss: 106.4020 - accuracy: 0.9763
#
# Epoch 00218: accuracy did not improve from 0.98273
# Epoch 219/600
# 15/15 [==============================] - 1s 59ms/step - loss: 124.9975 - accuracy: 0.9610
#
# Epoch 00219: accuracy did not improve from 0.98273
# Epoch 220/600
# 15/15 [==============================] - 1s 59ms/step - loss: 30.0337 - accuracy: 0.9725
#
# Epoch 00220: accuracy did not improve from 0.98273
# Epoch 221/600
# 15/15 [==============================] - 1s 58ms/step - loss: 20.2929 - accuracy: 0.9808
#
# Epoch 00221: accuracy did not improve from 0.98273
# Epoch 222/600
# 15/15 [==============================] - 1s 59ms/step - loss: 99.1601 - accuracy: 0.9731
#
# Epoch 00222: accuracy did not improve from 0.98273
# Epoch 223/600
# 15/15 [==============================] - 1s 59ms/step - loss: 178.0462 - accuracy: 0.9533
#
# Epoch 00223: accuracy did not improve from 0.98273
# Epoch 224/600
# 15/15 [==============================] - 1s 59ms/step - loss: 96.5750 - accuracy: 0.9699
#
# Epoch 00224: accuracy did not improve from 0.98273
# Epoch 225/600
# 15/15 [==============================] - 1s 59ms/step - loss: 41.7251 - accuracy: 0.9712
#
# Epoch 00225: accuracy did not improve from 0.98273
# Epoch 226/600
# 15/15 [==============================] - 1s 59ms/step - loss: 74.9772 - accuracy: 0.9718
#
# Epoch 00226: accuracy did not improve from 0.98273
# Epoch 227/600
# 15/15 [==============================] - 1s 59ms/step - loss: 56.4708 - accuracy: 0.9706
#
# Epoch 00227: accuracy did not improve from 0.98273
# Epoch 228/600
# 15/15 [==============================] - 1s 59ms/step - loss: 32.1263 - accuracy: 0.9827
#
# Epoch 00228: accuracy did not improve from 0.98273
# Epoch 229/600
# 15/15 [==============================] - 1s 59ms/step - loss: 48.2239 - accuracy: 0.9725
#
# Epoch 00229: accuracy did not improve from 0.98273
# Epoch 230/600
# 15/15 [==============================] - 1s 59ms/step - loss: 72.2572 - accuracy: 0.9789
#
# Epoch 00230: accuracy did not improve from 0.98273
# Epoch 231/600
# 15/15 [==============================] - 1s 59ms/step - loss: 177.8825 - accuracy: 0.9616
#
# Epoch 00231: accuracy did not improve from 0.98273
# Epoch 232/600
# 15/15 [==============================] - 1s 59ms/step - loss: 38.4566 - accuracy: 0.9591
#
# Epoch 00232: accuracy did not improve from 0.98273
# Epoch 233/600
# 15/15 [==============================] - 1s 59ms/step - loss: 55.9955 - accuracy: 0.9680
#
# Epoch 00233: accuracy did not improve from 0.98273
# Epoch 234/600
# 15/15 [==============================] - 1s 59ms/step - loss: 54.1520 - accuracy: 0.9635
#
# Epoch 00234: accuracy did not improve from 0.98273
# Epoch 235/600
# 15/15 [==============================] - 1s 59ms/step - loss: 34.5137 - accuracy: 0.9731
#
# Epoch 00235: accuracy did not improve from 0.98273
# Epoch 236/600
# 15/15 [==============================] - 1s 59ms/step - loss: 157.0341 - accuracy: 0.9738
#
# Epoch 00236: accuracy did not improve from 0.98273
# Epoch 237/600
# 15/15 [==============================] - 1s 59ms/step - loss: 75.0659 - accuracy: 0.9706
#
# Epoch 00237: accuracy did not improve from 0.98273
# Epoch 238/600
# 15/15 [==============================] - 1s 58ms/step - loss: 66.9611 - accuracy: 0.9667
#
# Epoch 00238: accuracy did not improve from 0.98273
# Epoch 239/600
# 15/15 [==============================] - 1s 59ms/step - loss: 95.9342 - accuracy: 0.9776
#
# Epoch 00239: accuracy did not improve from 0.98273
# Epoch 240/600
# 15/15 [==============================] - 1s 59ms/step - loss: 105.6905 - accuracy: 0.9808
#
# Epoch 00240: accuracy did not improve from 0.98273
# Epoch 241/600
# 15/15 [==============================] - 1s 59ms/step - loss: 46.9966 - accuracy: 0.9738
#
# Epoch 00241: accuracy did not improve from 0.98273
# Epoch 242/600
# 15/15 [==============================] - 1s 58ms/step - loss: 48.5616 - accuracy: 0.9821
#
# Epoch 00242: accuracy did not improve from 0.98273
# Epoch 243/600
# 15/15 [==============================] - 1s 59ms/step - loss: 127.7476 - accuracy: 0.9738
#
# Epoch 00243: accuracy did not improve from 0.98273
# Epoch 244/600
# 15/15 [==============================] - 1s 59ms/step - loss: 19.5409 - accuracy: 0.9789
#
# Epoch 00244: accuracy did not improve from 0.98273
# Epoch 245/600
# 15/15 [==============================] - 1s 59ms/step - loss: 47.7756 - accuracy: 0.9814
#
# Epoch 00245: accuracy did not improve from 0.98273
# Epoch 246/600
# 15/15 [==============================] - 1s 59ms/step - loss: 74.5971 - accuracy: 0.9603
#
# Epoch 00246: accuracy did not improve from 0.98273
# Epoch 247/600
# 15/15 [==============================] - 1s 58ms/step - loss: 68.3038 - accuracy: 0.9802
#
# Epoch 00247: accuracy did not improve from 0.98273
# Epoch 248/600
# 15/15 [==============================] - 1s 59ms/step - loss: 49.6469 - accuracy: 0.9802
#
# Epoch 00248: accuracy did not improve from 0.98273
# Epoch 249/600
# 15/15 [==============================] - 1s 58ms/step - loss: 100.4433 - accuracy: 0.9802
#
# Epoch 00249: accuracy did not improve from 0.98273
# Epoch 250/600
# 15/15 [==============================] - 1s 61ms/step - loss: 72.6231 - accuracy: 0.9635
#
# Epoch 00250: accuracy did not improve from 0.98273
# Epoch 251/600
# 15/15 [==============================] - 1s 58ms/step - loss: 28.1805 - accuracy: 0.9757
#
# Epoch 00251: accuracy did not improve from 0.98273
# Epoch 252/600
# 15/15 [==============================] - 1s 59ms/step - loss: 36.3638 - accuracy: 0.9808
#
# Epoch 00252: accuracy did not improve from 0.98273
# Epoch 253/600
# 15/15 [==============================] - 1s 58ms/step - loss: 81.1043 - accuracy: 0.9674
#
# Epoch 00253: accuracy did not improve from 0.98273
# Epoch 254/600
# 15/15 [==============================] - 1s 58ms/step - loss: 60.4644 - accuracy: 0.9744
#
# Epoch 00254: accuracy did not improve from 0.98273
# Epoch 255/600
# 15/15 [==============================] - 1s 59ms/step - loss: 69.7135 - accuracy: 0.9731
#
# Epoch 00255: accuracy did not improve from 0.98273
# Epoch 256/600
# 15/15 [==============================] - 1s 58ms/step - loss: 83.7650 - accuracy: 0.9827
#
# Epoch 00256: accuracy did not improve from 0.98273
# Epoch 257/600
# 15/15 [==============================] - 1s 59ms/step - loss: 68.4949 - accuracy: 0.9808
#
# Epoch 00257: accuracy did not improve from 0.98273
# Epoch 258/600
# 15/15 [==============================] - 1s 59ms/step - loss: 110.2368 - accuracy: 0.9782
#
# Epoch 00258: accuracy did not improve from 0.98273
# Epoch 259/600
# 15/15 [==============================] - 1s 59ms/step - loss: 32.5865 - accuracy: 0.9744
#
# Epoch 00259: accuracy did not improve from 0.98273
# Epoch 260/600
# 15/15 [==============================] - 1s 59ms/step - loss: 62.9011 - accuracy: 0.9712
#
# Epoch 00260: accuracy did not improve from 0.98273
# Epoch 261/600
# 15/15 [==============================] - 1s 58ms/step - loss: 42.7482 - accuracy: 0.9789
#
# Epoch 00261: accuracy did not improve from 0.98273
# Epoch 262/600
# 15/15 [==============================] - 1s 59ms/step - loss: 25.0630 - accuracy: 0.9770
#
# Epoch 00262: accuracy did not improve from 0.98273
# Epoch 263/600
# 15/15 [==============================] - 1s 59ms/step - loss: 73.2868 - accuracy: 0.9770
#
# Epoch 00263: accuracy did not improve from 0.98273
# Epoch 264/600
# 15/15 [==============================] - 1s 59ms/step - loss: 41.6476 - accuracy: 0.9834
#
# Epoch 00264: accuracy improved from 0.98273 to 0.98337, saving model to KSC-best-model.hdf5
# Epoch 265/600
# 15/15 [==============================] - 1s 58ms/step - loss: 91.9649 - accuracy: 0.9840
#
# Epoch 00265: accuracy improved from 0.98337 to 0.98401, saving model to KSC-best-model.hdf5
# Epoch 266/600
# 15/15 [==============================] - 1s 58ms/step - loss: 14.0826 - accuracy: 0.9808
#
# Epoch 00266: accuracy did not improve from 0.98401
# Epoch 267/600
# 15/15 [==============================] - 1s 58ms/step - loss: 157.8305 - accuracy: 0.9603
#
# Epoch 00267: accuracy did not improve from 0.98401
# Epoch 268/600
# 15/15 [==============================] - 1s 58ms/step - loss: 34.5340 - accuracy: 0.9840
#
# Epoch 00268: accuracy did not improve from 0.98401
# Epoch 269/600
# 15/15 [==============================] - 1s 58ms/step - loss: 50.8976 - accuracy: 0.9795
#
# Epoch 00269: accuracy did not improve from 0.98401
# Epoch 270/600
# 15/15 [==============================] - 1s 59ms/step - loss: 24.9959 - accuracy: 0.9795
#
# Epoch 00270: accuracy did not improve from 0.98401
# Epoch 271/600
# 15/15 [==============================] - 1s 62ms/step - loss: 114.3332 - accuracy: 0.9706
#
# Epoch 00271: accuracy did not improve from 0.98401
# Epoch 272/600
# 15/15 [==============================] - 1s 61ms/step - loss: 69.5597 - accuracy: 0.9834
#
# Epoch 00272: accuracy did not improve from 0.98401
# Epoch 273/600
# 15/15 [==============================] - 1s 60ms/step - loss: 73.0851 - accuracy: 0.9808
#
# Epoch 00273: accuracy did not improve from 0.98401
# Epoch 274/600
# 15/15 [==============================] - 1s 61ms/step - loss: 59.3169 - accuracy: 0.9846
#
# Epoch 00274: accuracy improved from 0.98401 to 0.98464, saving model to KSC-best-model.hdf5
# Epoch 275/600
# 15/15 [==============================] - 1s 62ms/step - loss: 54.4172 - accuracy: 0.9750
#
# Epoch 00275: accuracy did not improve from 0.98464
# Epoch 276/600
# 15/15 [==============================] - 1s 62ms/step - loss: 214.9045 - accuracy: 0.9763
#
# Epoch 00276: accuracy did not improve from 0.98464
# Epoch 277/600
# 15/15 [==============================] - 1s 61ms/step - loss: 48.8872 - accuracy: 0.9744
#
# Epoch 00277: accuracy did not improve from 0.98464
# Epoch 278/600
# 15/15 [==============================] - 1s 61ms/step - loss: 110.6877 - accuracy: 0.9814
#
# Epoch 00278: accuracy did not improve from 0.98464
# Epoch 279/600
# 15/15 [==============================] - 1s 60ms/step - loss: 96.0221 - accuracy: 0.9552
#
# Epoch 00279: accuracy did not improve from 0.98464
# Epoch 280/600
# 15/15 [==============================] - 1s 61ms/step - loss: 49.0184 - accuracy: 0.9744
#
# Epoch 00280: accuracy did not improve from 0.98464
# Epoch 00280: early stopping

# %% [markdown]
# # Validation

# %%
# Saves, but does not display, the history charts
fig = plt.figure(figsize=(7,7)) 
plt.ioff()
plt.grid() 
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.ylabel('Loss') 
plt.xlabel('Epochs') 
plt.legend(['Training','Validation'], loc='upper right') 
plt.savefig(loss_curve) 
plt.close(fig)

fig = plt.figure(figsize=(7,7)) 
plt.ioff()
plt.ylim(np.min(history.history['accuracy']),1.05) 
plt.grid() 
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_acc'])
plt.ylabel('Accuracy') 
plt.xlabel('Epochs') 
plt.legend(['Training','Validation']) 
plt.savefig(acc_curve) 
plt.close(fig)

# %%
# Displays history of training
# loss and accuracy by epoch, side by side

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 7))
ax1.grid() 
ax1.plot(history.history['loss'])
ax1.set_ylabel('Loss') 
ax1.set_xlabel('Epochs') 
ax1.legend(['Training','Validation'], loc='upper right') 

ax2.set_ylim(np.min(history.history['accuracy']),1.05) 
ax2.grid() 
ax2.plot(history.history['accuracy'])
ax2.set_ylabel('Accuracy') 
ax2.set_xlabel('Epochs') 
ax2.legend(['Training','Validation']) 
plt.show() # plt.tight_layout()

# %%
# load best weights
model.load_weights(best_model)
model.compile(loss='categorical_crossentropy', optimizer=FuncOptimizer, metrics=['accuracy'])

# %%
Xtest = Xtest.reshape(-1, window_size, window_size, num_channels) #, 1)
Xtest.shape
# Out:
# (3648, 27, 27, 10)

# %%
Ytest = np_utils.to_categorical(ytest)
Ytest.shape
# Out:
# (3648, 13)

# %%
Y_pred_test = model.predict(Xtest)
y_pred_test = np.argmax(Y_pred_test, axis=1)

# %%
print(y_pred_test.shape) 
classification = classification_report(np.argmax(Ytest, axis=1), y_pred_test,digits=4)
print(classification)
# Out:
# (3648,)
#               precision    recall  f1-score   support
#
#            0     0.9757    0.9775    0.9766       533
#            1     0.8404    0.9294    0.8827       170
#            2     1.0000    0.9721    0.9858       179
#            3     0.9263    0.5000    0.6494       176
#            4     0.8862    0.9646    0.9237       113
#            5     0.9455    0.9750    0.9600       160
#            6     1.0000    0.6486    0.7869        74
#            7     0.9593    0.8576    0.9056       302
#            8     0.9721    0.9560    0.9640       364
#            9     0.9126    0.9223    0.9174       283
#           10     0.8359    0.9215    0.8766       293
#           11     0.7662    0.9403    0.8444       352
#           12     0.9923    0.9969    0.9946       649
#
#     accuracy                         0.9238      3648
#    macro avg     0.9240    0.8894    0.8975      3648
# weighted avg     0.9295    0.9238    0.9214      3648

# %%
def AA_andEachClassAccuracy(confusion_matrix):
    counter = confusion_matrix.shape[0]
    list_diag = np.diag(confusion_matrix)
    list_row_sum = np.sum(confusion_matrix, axis=1)
    each_acc = np.nan_to_num(truediv(list_diag, list_row_sum))
    average_acc = np.mean(each_acc)
    return each_acc, average_acc

# %%
def get_targets(name):
    targets_dict = {
        'IP': ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn', 'Grass-pasture', 'Grass-trees', 'Grass-pasture-mowed',
               'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill', 'Soybean-clean', 'Wheat', 'Woods', 
               'Buildings-Grass-Trees-Drives', 'Stone-Steel-Towers'],
        'SA': ['Brocoli_green_weeds_1', 'Brocoli_green_weeds_2', 'Fallow', 'Fallow_rough_plow', 'Fallow_smooth', 'Stubble',
               'Celery','Grapes_untrained', 'Soil_vinyard_develop', 'Corn_senesced_green_weeds', 'Lettuce_romaine_4wk',
               'Lettuce_romaine_5wk', 'Lettuce_romaine_6wk', 'Lettuce_romaine_7wk', 'Vinyard_untrained',
               'Vinyard_vertical_trellis'],
        'PU': ['Asphalt', 'Meadows', 'Gravel', 'Trees', 'Painted metal sheets', 'Bare Soil', 'Bitumen', 'Self-Blocking Bricks',
               'Shadows'],
        'KS': ['Scrub', 'Willow swamp', 'Cabbage palm hammock', 'Cabbage palm/oak hammock', 'Slash pine', 'Oak/broadleaf hammock',
                'Hardwood swamp', 'Graminoid marsh', 'Spartina marsh', 'Cattail marsh', 'Salt marsh', 'Mud flats', 'Water']
    }
    targets = targets_dict.get(name)
    return (targets)


print(', '.join(get_targets(dataset[0:2].upper())))

def reports (model, X_test, y_test, name, y_pred = None):
    #start = time.time()
    if (y_pred is None):
        Y_pred = model.predict(X_test)
        y_pred = np.argmax(Y_pred, axis=1)
    #end = time.time()
    #print(end - start)
    target_names = get_targets(name[0:2].upper())
    print("Producing report")
    classification = classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names)
    oa = accuracy_score(np.argmax(y_test, axis=1), y_pred)
    confusion = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
    each_acc, aa = AA_andEachClassAccuracy(confusion)
    kappa = cohen_kappa_score(np.argmax(y_test, axis=1), y_pred)
    score = model.evaluate(X_test, y_test, batch_size=32)
    Test_Loss =  score[0]*100
    Test_accuracy = score[1]*100
    
    return classification, confusion, Test_Loss, Test_accuracy, oa*100, each_acc*100, aa*100, kappa*100, target_names
# Out:
# Scrub, Willow swamp, Cabbage palm hammock, Cabbage palm/oak hammock, Slash pine, Oak/broadleaf hammock, Hardwood swamp, Graminoid marsh, Spartina marsh, Cattail marsh, Salt marsh, Mud flats, Water

# %%
(classification, confusion, Test_loss, Test_accuracy, 
 oa, each_acc, aa, kappa, target_names) = reports(model, Xtest, Ytest, dataset[0:2], y_pred=y_pred_test)
# Out:
# Producing report
# 114/114 [==============================] - 1s 10ms/step - loss: 1292.1489 - accuracy: 0.9238

# %%
target_performance = 'Accuracy by target:\n'
for (a, b) in zip(target_names, each_acc):
    target_performance += f'{b:8.4f} : {a}\n'
print(target_performance)
# Out:
# Accuracy by target:
#  97.7486 : Scrub
#  92.9412 : Willow swamp
#  97.2067 : Cabbage palm hammock
#  50.0000 : Cabbage palm/oak hammock
#  96.4602 : Slash pine
#  97.5000 : Oak/broadleaf hammock
#  64.8649 : Hardwood swamp
#  85.7616 : Graminoid marsh
#  95.6044 : Spartina marsh
#  92.2261 : Cattail marsh
#  92.1502 : Salt marsh
#  94.0341 : Mud flats
#  99.6918 : Water

# %%
import seaborn as sns
cf_matrix = np.asarray(confusion)
sns_plot=sns.heatmap(cf_matrix, annot=False, xticklabels=target_names, yticklabels=target_names)
sns_plot.figure.savefig(str(dataset)+'-heatmap.png', dpi=600)
#plt.savefig(str(dataset)+'-heatmap.png')

# %%
classification = str(classification)
confusion = str(confusion)
confusion=confusion.replace('\n', '')
confusion=confusion.replace('] [', ']\n[')
confusion=confusion.replace('][', ']\n[')
dim_reduction='pca'
c_summary = 'Classification Summary\n'
c_summary += f'{Test_loss:7.3f} Test loss (%)\n'
c_summary += f'{Test_accuracy:7.3f} Test accuracy (%)\n'
c_summary += f'{kappa:7.3f} Kappa accuracy (%)\n'
c_summary += f'{oa:7.3f} Overall accuracy (%)\n'
c_summary += f'{aa:7.3f} Average accuracy (%)\n\n'

c_summary += f'{classification}\n\n'
c_summary += f'{confusion}\n\n'

model_summary = []
model.summary(print_fn=lambda x: model_summary.append(x)) # line_length=70,
model_summary = '\n'.join(model_summary)
model_summary += '\n\n'

print(c_summary)
print(target_performance+'\n\n')
print(model_summary)
print(config_txt)

with open(classification_file, 'w') as cs_file:
    cs_file.write(c_summary)
    cs_file.write(target_performance+'\n\n')
    cs_file.write(model_summary)
    cs_file.write(config_txt)
# Out:
# Classification Summary
# 129214.893 Test loss (%)
#  92.379 Test accuracy (%)
#  91.504 Kappa accuracy (%)
#  92.379 Overall accuracy (%)
#  88.938 Average accuracy (%)
#
#                           precision    recall  f1-score   support
#
#                    Scrub       0.98      0.98      0.98       533
#             Willow swamp       0.84      0.93      0.88       170
#     Cabbage palm hammock       1.00      0.97      0.99       179
# Cabbage palm/oak hammock       0.93      0.50      0.65       176
#               Slash pine       0.89      0.96      0.92       113
#    Oak/broadleaf hammock       0.95      0.97      0.96       160
#           Hardwood swamp       1.00      0.65      0.79        74
#          Graminoid marsh       0.96      0.86      0.91       302
#           Spartina marsh       0.97      0.96      0.96       364
#            Cattail marsh       0.91      0.92      0.92       283
#               Salt marsh       0.84      0.92      0.88       293
#                Mud flats       0.77      0.94      0.84       352
#                    Water       0.99      1.00      0.99       649
#
#                 accuracy                           0.92      3648
#                macro avg       0.92      0.89      0.90      3648
#             weighted avg       0.93      0.92      0.92      3648
#
#
# [[521   0   0   0   3   8   0   0   0   0   1   0   0]
# [  1 158   0   0   0   0   0   2   0   2   5   2   0]
# [  0   0 174   0   0   0   0   1   2   2   0   0   0]
# [  0   2   0  88   1   1   0   6   0   1  18  58   1]
# [  0   0   0   0 109   0   0   0   0   4   0   0   0]
# [  0   2   0   0   0 156   0   0   0   0   0   0   2]
# [  7  17   0   1   0   0  48   0   0   0   1   0   0]
# [  5   7   0   1   0   0   0 259   3   3   9  15   0]
# [  0   0   0   0   0   0   0   0 348  12   1   3   0]
# [  0   0   0   3   8   0   0   0   1 261   0  10   0]
# [  0   2   0   0   1   0   0   0   4   1 270  13   2]
# [  0   0   0   2   1   0   0   0   0   0  18 331   0]
# [  0   0   0   0   0   0   0   2   0   0   0   0 647]]
#
#
# Accuracy by target:
#  97.7486 : Scrub
#  92.9412 : Willow swamp
#  97.2067 : Cabbage palm hammock
#  50.0000 : Cabbage palm/oak hammock
#  96.4602 : Slash pine
#  97.5000 : Oak/broadleaf hammock
#  64.8649 : Hardwood swamp
#  85.7616 : Graminoid marsh
#  95.6044 : Spartina marsh
#  92.2261 : Cattail marsh
#  92.1502 : Salt marsh
#  94.0341 : Mud flats
#  99.6918 : Water
#
#
#
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 27, 27, 10)] 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 96)   1056        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 27, 27, 16)   176         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 27, 27, 10)   0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 27, 27, 256)  2816        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 27, 27, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 27, 27, 128)  51328       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 27, 27, 128)  100480      conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 27, 27, 64)   83008       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 27, 27, 32)   352         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 7290)         0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 27, 27, 736)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           116656      flatten_1[0][0]
# __________________________________________________________________________________________________
# avg_pooling (AveragePooling2D)  (None, 25, 25, 736)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 460000)       0           avg_pooling[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           272         dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           7360016     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dropout_2[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           1056        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 13)           429         dropout_3[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 13)           0           dense_4[0][0]
# ==================================================================================================
# Total params: 7,828,717
# Trainable params: 7,828,717
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#
# Configuration for dataset [KSC]:
#
# Test Set Ratio: 70.0% of samples
# Window Size   : 27 pixels per side
# Dim. Reduction: svd function
# Num channels  : 10 bands after svd
# # Network design
# Input shape   : (27x27x10)
# HSI Filters   : None filters in first layer
# Internal Size : (9x9) maximum network filter size
# # Training hyperparameters
# Optimizer     : adadelta
# Learning rate : 1.0
# Batch Size    : 106
# Num Epochs    : 600
# Patience      : 70
# # Training GPUs
# GPU Maximum   : 1

# %%
def Patch(data, height_index, width_index, PATCH_SIZE):
    height_slice = slice(height_index, height_index+PATCH_SIZE)
    width_slice = slice(width_index, width_index+PATCH_SIZE)
    patch = data[height_slice, width_slice, :]
    
    return patch

# %%
height = HSI_y.shape[0]
width  = HSI_y.shape[1]

# %%
X = padWithZeros(DRI, window_size//2)

# %%
X.shape
# Out:
# (538, 640, 10)

# %%
from tqdm import tqdm
# calculate the predicted image
outputs = np.zeros((height,width))
#for i in range(height):
for i in tqdm(range(height), desc="Predicting...",
                          ascii=False, ncols=75):
    for j in range(width):
        target = int(HSI_y[i,j])
        if target == 0 :
            continue
        else :
            image_patch=Patch(X, i, j, window_size)
            X_test_image = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1], image_patch.shape[2]).astype('float32')                                   
            prediction = (model.predict(X_test_image))
            prediction = np.argmax(prediction, axis=1)
            outputs[i][j] = prediction+1
# Out:
# Predicting...: 100%|█████████████████████| 512/512 [02:36<00:00,  3.26it/s]

# %%
ground_truth = spectral.imshow(classes = HSI_y,figsize =(7,7))

# %%
predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(7,7))

# %%
from matplotlib.colors import ListedColormap, NoNorm

cm = ListedColormap(np.array(spectral.spy_colors)/255.0)
delta = (np.abs(outputs.astype(int) - HSI_y)>0)*1
print('Misclassified pixels: ', np.sum(np.asarray(delta)>0), "/", delta.shape[0]*delta.shape[1])
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(15,8))
ax1.set_title("Ground truth")
ax2.set_title("Prediction")
ax3.set_title("Delta")
ax1.imshow(HSI_y) #, cmap=cm, norm=NoNorm())
ax2.imshow(outputs.astype(int)) #, cmap=cm, norm=NoNorm())
ax3.imshow(delta, cmap=cm)
plt.tight_layout()
# Out:
# Misclassified pixels:  278 / 314368

# %%
spectral.save_rgb(str(dataset)+"-ground_truth.png", HSI_y, colors=spectral.spy_colors)
spectral.save_rgb(str(dataset)+"-delta.png", delta, colors=spectral.spy_colors)
spectral.save_rgb(predictions_img, outputs.astype(int), colors=spectral.spy_colors)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(np.argmax(Ytest, axis=1), y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap=plt.cm.Blues,xticks_rotation="vertical")

# %%
#del model
#print("Keras Backend RESET")  # optional
#import keras
#import gc
#keras.backend.clear_session()
#tf.keras.backend.clear_session()
#gc.collect()
